# %% [markdown]
# Estudiante: José Luis San Martín

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataFrame = pd.read_csv("Wine.csv")
dataFrame.head(10)
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
# 5    14.20        1.76  2.45          15.2        112           3.27
# 6    14.39        1.87  2.45          14.6         96           2.50
# 7    14.06        2.15  2.61          17.6        121           2.60
# 8    14.83        1.64  2.17          14.0         97           2.80
# 9    13.86        1.35  2.27          16.0         98           2.98
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# ...

# %% [markdown]
# ## Analisis exploratorio

# %%
dataFrame.shape
# Out:
# (178, 14)

# %% [markdown]
# Se aprecia que el dataframe esta compuesto por 178 filas y 14 columnas

# %%
dataFrame.dtypes
# Out:
# Alcohol                 float64
# Malic_Acid              float64
# Ash                     float64
# Ash_Alcanity            float64
# Magnesium                 int64
# Total_Phenols           float64
# Flavanoids              float64
# Nonflavanoid_Phenols    float64
# Proanthocyanins         float64
# Color_Intensity         float64
# Hue                     float64
# OD280                   float64
# Proline                   int64
# Customer_Segment          int64
# dtype: object

# %%
dataFrame.groupby('Customer_Segment').size()
# Out:
# Customer_Segment
# 1    59
# 2    71
# 3    48
# dtype: int64

# %% [markdown]
# En el dataframe hay 3 segmentos de clientes. Siendo el numero 1 compuesto por 59 clientes, el numero 2 compuesto por 71 y el numero esta compuesto por 48 clientes.

# %% [markdown]
# ## Histogras de los datos

# %% [markdown]
# ### Alcohol

# %%
dataFrame.drop(1).hist(['Alcohol'],color='darkorange',edgecolor='black', linewidth=1)
plt.title('Alcohol')
plt.xlabel('Grados de Alcohol')
plt.ylabel('Observaciones')
plt.show()

# %% [markdown]
# De este histograma referente al Alcohol se interpreta que la cantidad de Alcohol mas comun de encontrar es a partir de los 12 grados de Alcohol con mas de 150 observaciones y las cantidad de grados de Alcohol menos comun de encontrar son las menores a 11.5 grados y superiores a 14.5 grados.

# %% [markdown]
# ### Ácido málico

# %% [markdown]
# El acido malico es un compuesto que se encuentra en frutas y vegetales, ademas es saludable para el organismo. Le da un sabor amargo y perdurable al paladar a los alimentos.

# %%
dataFrame.drop(1).hist(['Malic_Acid'],color='darkorange',edgecolor='black', linewidth=1)
plt.title('Ácido málico')
plt.xlabel('Cantidad de Ácido málico')
plt.ylabel('Observaciones')
plt.show()

# %% [markdown]
# En el histograma se aprecia que la moda de para los datos es de alrrededor de 1.5 de acido masico, con cerca de 60 observaciones y las cantidades de acido masico mas raras de ver es apartir de 5.

# %% [markdown]
# ### Ceniza

# %% [markdown]
# La ceniza u oídio de la vid es una hongo que afecta a las hojas, brotes y racimos de la frutaa. Esto afecta a la calidad de la uva y a su ves a la calidad del vino en este caso. Esto da a entender que entre mayor sea la cantidad de ceniza menor sera la calidad del vino siendo las variables de cantidad de ceniza y calidad de vino inversamente proporcionales.

# %%
dataFrame.drop(1).hist(['Ash'],color='darkorange',edgecolor='black', linewidth=1)
plt.title('Ceniza')
plt.xlabel('Cantidad de ceniza')
plt.ylabel('Observaciones')
plt.show()

# %% [markdown]
# La cantidad de ceniza presente en los vinos en este caso se encuentra de cierta manera normalizada siendo los datos centrales aquellos con mayor cantidad de observacones, estos son a partir de 2.25 y 2.50. Los datos de los extremos con una ocurrencia menor estos son los datos menores a 1.75 y mayores 3.00.

# %% [markdown]
# ### Magnesio

# %% [markdown]
# El sabor acido del vino esta relacionado con la cantidad de mangnesio que posea. Siendo estas variables directamente proporcionales mientras mas magnasio contenga el vino, su sabor sera mas acido

# %%
dataFrame.drop(1).hist(['Magnesium'],color='darkorange',edgecolor='black', linewidth=1)
plt.title('Magnesio')
plt.xlabel('Cantidad de Magnesio')
plt.ylabel('Observaciones')
plt.show()

# %% [markdown]
# La cantida de magnasio en los vinos  que mas se repite esta entre 80 y 120. Representando esto mas de 120 muestras del data frame. Los valores mayores a 120 de cantidad de magnesio seria los que representan a los vinos mas acidos, que en el grafico como se logra apreciar son los menores. Los vinos de menos de 80 de cantidad de magnesio tambien son una minoria representando los vinos menos acidos.

# %% [markdown]
# ### Fenoles

# %% [markdown]
# Los fenoles se encargan de dar el aroma al vino y tambien otorgan cualidades a la vid. Siendo al igual que la cualidad anterior una variable con relacion directa en relacion con su presencia en el vino y el aroma que produce.

# %%
dataFrame.drop(1).hist(['Total_Phenols'],color='darkorange',edgecolor='black', linewidth=1)
plt.title('Fonoles totales')
plt.xlabel('Cantidad de Fenol')
plt.ylabel('Observaciones')
plt.show()

# %% [markdown]
# A diferencia de los histogramas anteriores en este atributo se muestra mayor diversidad, no mostrando una clara tendencia a excepcion de los extremos. Como los fenoles se encargan de dar aroma a los vinos y al haber mucha divsersidad en este caso concuerda con los diversos aromas de vinos que excisten por eso se muestra esa diversidad en el hidtograma

# %% [markdown]
# ### Flavonoides

# %% [markdown]
# Los flavonoides se encargan de dar color , sabor y otras propiedades al vino

# %%
dataFrame.drop(1).hist(['Flavanoids'],color='darkorange',edgecolor='black', linewidth=1)
plt.title('Flavanoides')
plt.xlabel('Cantidad de Flavanoides')
plt.ylabel('Observaciones')
plt.show()

# %% [markdown]
# En el grafico se interpreta que al igual que el anterior hay divesidad entre las observaciones donde hay sobre 30 vinos que casi no poseen flanovoides y tambien hay bastantes que poseen flavonoides en su composicion

# %% [markdown]
# ### intensidad del color

# %%
dataFrame.drop(1).hist(['Color_Intensity'],color='darkorange',edgecolor='black', linewidth=1)
plt.title('Intensidad del color')
plt.xlabel('Nivel de intensidad')
plt.ylabel('Observaciones')
plt.show()

# %% [markdown]
# En el histograma de intesidad de color se observa que la el nivel mas comun de color a encontrar es del 3 al 6 y es mas raro encontrar un vino cono una intesidad de color de un nivel sobre el 8.

# %% [markdown]
# ### Matiz

# %% [markdown]
# La matiz hace referencia a la tonalidad del vino, a partir de esta tonalidad se puede obtener informacion sobre su edad

# %%
dataFrame.drop(1).hist(['Hue'],color='darkorange',edgecolor='black', linewidth=1)
plt.title('Matiz o tonalidad del vino')
plt.xlabel('Nivel de tonalidad')
plt.ylabel('Observaciones')
plt.show()

# %%
dataFrame['Hue'].min()
# Out:
# 0.48

# %%
dataFrame['Hue'].max()
# Out:
# 1.71

# %% [markdown]
# En el histograma se logra apreciar nivel de tonalidad que va desde los 0.48 hasta 1.4 donde es bastante comun encontrar un vino de estos rangos de tonalidad ya que abarcan casi la totalidad de los datos

# %% [markdown]
# ### OD280

# %% [markdown]
# Indice de vinos diluidos

# %%
dataFrame.drop(1).hist(['OD280'],color='darkorange',edgecolor='black', linewidth=1)
plt.title('Indice de vino diluido')
plt.xlabel('Nivel OD280')
plt.ylabel('Observaciones')
plt.show()

# %% [markdown]
# ### Prolina

# %%
Aminoacido que el vino contiene
# Out:
#   File "<ipython-input-218-05d057623ebd>", line 1
#     Aminoacido que el vino contiene
#                ^
# SyntaxError: invalid syntax

# %%
dataFrame.drop(1).hist(['Proline'],color='darkorange',edgecolor='black', linewidth=1)
plt.title('Prolina')
plt.xlabel('Cantidad de prolina')
plt.ylabel('Observaciones')
plt.show()

# %% [markdown]
# ### Segmentos de clientes

# %%
tipos = dataFrame['Customer_Segment'].unique()
total = dataFrame['Customer_Segment'].value_counts().tolist()
plt.pie(total, labels=tipos, autopct='%1.1f%%', shadow=True, startangle=90) 
plt.title('Segmentos de clientes')
plt.show()

# %% [markdown]
# De las 178 obesrvaciones del data frame 39.9% (71 clientes) pertenecen al grupo 1, 33.1% (59 clientes) pertencen al grupo 2 y 27 (48 clientes) pertenecen al grupo 3.

# %% [markdown]
# # Variable Categorica

# %% [markdown]
# La variable categorica sera segmento de clientes

# %% [markdown]
# # Graficos de dispresion

# %% [markdown]
# Para ver la correlacion de la variable categorica con las demas variables

# %%
import seaborn as sb
sb.pairplot(dataFrame.dropna(),hue='Customer_Segment',height=4,vars=["Alcohol","Malic_Acid","Ash","Ash_Alcanity"],kind='scatter')

# %%
import seaborn as sb
sb.pairplot(dataFrame.dropna(),hue='Customer_Segment',height=4,vars=["Proanthocyanins","Color_Intensity","Hue","OD280"],kind='scatter')

# %%
import seaborn as sb
sb.pairplot(dataFrame.dropna(),hue='Customer_Segment',height=4,vars=["Proline"],kind='scatter')

# %%
import seaborn as sb
sb.pairplot(dataFrame.dropna(),hue='Customer_Segment',height=4,vars=["Malic_Acid","Ash_Alcanity","Nonflavanoid_Phenols"],kind='scatter')

# %% [markdown]
# Las variables con una buena correlacion con la variable categorica son:
#
# *Acido malico(Malic_Acid), la cual le da un sabor amargo al vino.
#
# *alcalinidad de cenizas (Ash_Alcanity), al tener poca de esta sustancia le otorga calidad al vino.
#
# *Fenoles no flavonoides(Nonflavanoid_Phenols), Le da aroma al vino.

# %% [markdown]
# Se selececciono 3 dimensiones las que se cree que son las mas importantes a la hora de que un consumidor escoja un vino, estas son: Calidad, sabor y aroma. Ademas presentar una buena correlacion en los graficos anteriores

# %% [markdown]
# # Limpieza de datos

# %%
df = dataFrame.rename_axis('index').reset_index()
df.head()
# Out:
#    index  Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      0    14.23        1.71  2.43          15.6        127           2.80
# 1      1    13.20        1.78  2.14          11.2        100           2.65
# 2      2    13.16        2.36  2.67          18.6        101           2.80
# 3      3    14.37        1.95  2.50          16.8        113           3.85
# 4      4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# ...

# %% [markdown]
# Antes de comenzar la limpieza de los datos se le coloco un indice a cada elemento del data frame para facilitar su localizacion

# %% [markdown]
# ### Detectando outliers en Acido malico

# %%
plt.boxplot(df["Malic_Acid"], vert=False)
plt.title('Caja de bigotes para Acido malico')
plt.xlabel('Acido malico')
plt.show()

# %%
x_values = df.Malic_Acid.unique()
y_values = df.Malic_Acid.value_counts().tolist()
plt.scatter(x_values, y_values, marker='o');
plt.title('Densidad de datos')
plt.xlabel('Malic_Acid')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# Cómo se aprecia tanto en el gráfico caja de bigotes como en el de dispersión hay valores outliers en la columna acido mailico, ahora se trabajara en esa columna y se eliminaran.

# %%
Q1 = df['Malic_Acid'].quantile(0.25)
print("Primer cuartil:", Q1)
Q3 = df['Malic_Acid'].quantile(0.75)
print("Segundo cuartil:", Q3)
IQR = Q3-Q1
print("Rango intercuartil", IQR)
mediana = df['Malic_Acid'].median()
print("Mediana:",mediana)
valor_maximo = df['Malic_Acid'].max()
print("Valor maximo:",valor_maximo)
valor_minimo = df['Malic_Acid'].min()
print("Valor minimo:", valor_minimo)
# Out:
# Primer cuartil: 1.6025000000000003
# Segundo cuartil: 3.0825
# Rango intercuartil 1.4799999999999998
# Mediana: 1.8650000000000002
# Valor maximo: 5.8
# Valor minimo: 0.74

# %%
valor_inferior = (Q1-1.5*IQR)
print("Valor inferior:",valor_inferior)
valor_superior = (Q3+1.5*IQR)
print("Valor superior:",valor_superior)
# Out:
# Valor inferior: -0.6174999999999995
# Valor superior: 5.3025

# %%
valores_outliers = (df['Malic_Acid'] < valor_inferior) | (df['Malic_Acid'] > valor_superior)  
print("outliers \n",valores_outliers)
# Out:
# outliers
#  0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 173     True
# 174    False
# 175    False
# 176    False
# 177    False
# Name: Malic_Acid, Length: 178, dtype: bool

# %% [markdown]
# ### Outliers

# %%
total_outliers = df[valores_outliers]
outliers = total_outliers.sort_values("index")
outliers
# Out:
#      index  Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 123    123    13.05        5.80  2.13          21.5         86           2.62
# 137    137    12.53        5.51  2.64          25.0         96           1.79
# 173    173    13.71        5.65  2.45          20.5         95           1.68
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 123        2.65                  0.30             2.01              2.6  0.73
# 137        0.60                  0.63             1.10              5.0  0.82
# 173        0.61                  0.52             1.06              7.7  0.64
#
#      OD280  Proline  Customer_Segment
# 123   3.10      380                 2
# 137   1.69      515                 3
# 173   1.74      740                 3

# %% [markdown]
# ### No outliers

# %%
valores_no_outliers = (df['Malic_Acid'] >= valor_inferior) & (df['Malic_Acid'] <= valor_superior)
print("No outliers \n",valores_no_outliers)
# Out:
# No outliers
#  0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 173    False
# 174     True
# 175     True
# 176     True
# 177     True
# Name: Malic_Acid, Length: 178, dtype: bool

# %%
df_1 = df[valores_no_outliers]
df_1.shape
# Out:
# (175, 15)

# %% [markdown]
# ### Detectando outliers en alcalinidad de cenizas

# %%
plt.boxplot(df_1["Ash_Alcanity"], vert=False)
plt.title('Caja de bigotes para alcalinidad de cenizas')
plt.xlabel('alcalinidad de cenizas')
plt.show()

# %%
x_values = df_1.Ash_Alcanity.unique()
y_values = df_1.Ash_Alcanity.value_counts().tolist()
plt.scatter(x_values, y_values, marker='o');
plt.title('Densidad de datos')
plt.xlabel('alcalinidad de cenizas')
plt.ylabel('Frecuencia')
plt.show()

# %%
Q1 = df_1['Ash_Alcanity'].quantile(0.25)
print("Primer cuartil:", Q1)
Q3 = df_1['Ash_Alcanity'].quantile(0.75)
print("Segundo cuartil:", Q3)
IQR = Q3-Q1
print("Rango intercuartil", IQR)
mediana = df_1['Ash_Alcanity'].median()
print("Mediana:",mediana)
valor_maximo = df_1['Ash_Alcanity'].max()
print("Valor maximo:",valor_maximo)
valor_minimo = df_1['Ash_Alcanity'].min()
print("Valor minimo:", valor_minimo)
# Out:
# Primer cuartil: 17.15
# Segundo cuartil: 21.5
# Rango intercuartil 4.350000000000001
# Mediana: 19.4
# Valor maximo: 30.0
# Valor minimo: 10.6

# %%
valor_inferior = (Q1-1.5*IQR)
print("Valor inferior:",valor_inferior)
valor_superior = (Q3+1.5*IQR)
print("Valor superior:",valor_superior)
# Out:
# Valor inferior: 10.624999999999996
# Valor superior: 28.025000000000002

# %%
valores_outliers = (df_1['Ash_Alcanity'] < valor_inferior) | (df_1['Ash_Alcanity'] > valor_superior)  
print("outliers \n",valores_outliers)
# Out:
# outliers
#  0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 172    False
# 174    False
# 175    False
# 176    False
# 177    False
# Name: Ash_Alcanity, Length: 175, dtype: bool

# %% [markdown]
# ### Outliers

# %%
total_outliers = df_1[valores_outliers]
outliers = total_outliers.sort_values("index")
outliers
# Out:
#      index  Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 59      59    12.37        0.94  1.36          10.6         88           1.98
# 73      73    12.99        1.67  2.60          30.0        139           3.30
# 121    121    11.56        2.05  3.23          28.5        119           3.18
# 127    127    11.79        2.13  2.78          28.5         92           2.13
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 59         0.57                  0.28             0.42             1.95  1.05
# 73         2.89                  0.21             1.96             3.35  1.31
# 121        5.08                  0.47             1.87             6.00  0.93
# 127        2.24                  0.58             1.76             3.00  0.97
#
#      OD280  Proline  Customer_Segment
# 59    1.82      520                 2
# 73    3.50      985                 2
# 121   3.69      465                 2
# ...

# %% [markdown]
# ### No outliers

# %%
valores_no_outliers = (df_1['Ash_Alcanity'] >= valor_inferior) & (df_1['Ash_Alcanity'] <= valor_superior)
print("No outliers \n",valores_no_outliers)
# Out:
# No outliers
#  0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 172    True
# 174    True
# 175    True
# 176    True
# 177    True
# Name: Ash_Alcanity, Length: 175, dtype: bool

# %%
df_2 = df_1[valores_no_outliers]
df_2.shape
# Out:
# (171, 15)

# %% [markdown]
# ### Detectando outliers en Fenoles no flavonoides

# %%
plt.boxplot(df_2["Nonflavanoid_Phenols"], vert=False)
plt.title('Caja de bigotes para Fenoles no flavonoides')
plt.xlabel('Fenoles no flavonoides')
plt.show()

# %%
x_values = df_2.Nonflavanoid_Phenols.unique()
y_values = df_2.Nonflavanoid_Phenols.value_counts().tolist()
plt.scatter(x_values, y_values, marker='o');
plt.title('Densidad de datos')
plt.xlabel('Fenoles no flavonoides')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ## Guardando los datos limpios en otro archivo csv

# %%
df_2.to_csv('clean_wine.csv', header=True, index=False)

# %% [markdown]
# # Preparacion de los datos

# %%
from mpl_toolkits.mplot3d import Axes3D

X = np.array(df_2[["Malic_Acid","Ash_Alcanity","Nonflavanoid_Phenols"]])
y = np.array(df_2['Customer_Segment'])
fig = plt.figure(figsize=(10,10))
ax = Axes3D(fig)
colores = ['green','red','yellow','blue']
#Si se asigna la posicion 0 del array repetida pues las categorias comienzan en id 1
asignar=[]
for row in y:
    asignar.append(colores[row])
ax.scatter(X[:,0],X[:,1],X[:,2], c=asignar, s=60)
plt.show()

# %% [markdown]
# Los 3 segmentos de clientes en relacion a las variables, que tienen una correlacion ma alta. Sabor amargo, calidad y aroma

# %% [markdown]
# # Algoritmo

# %%
from sklearn.cluster import KMeans
num_clusters = range(1,20)
kmeans = [KMeans(n_clusters=i) for i in num_clusters]
kmeans
score = [kmeans[i].fit(X).score(X) for i in range(len(kmeans))]
score
plt.plot(num_clusters,score, color="orange")
plt.xlabel('Número de Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %% [markdown]
# la Curva de Elbow se quebra con mayor notoriedad en cluster 5, es por esto que se trabajara con un k=5.

# %% [markdown]
# # Ejecucion del algoritmo

# %%
kmeans = KMeans(n_clusters=5).fit(X)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[ 2.48754386 19.24561404  0.36473684]
#  [ 2.045      12.85        0.2825    ]
#  [ 2.49222222 24.75555556  0.39777778]
#  [ 2.76153846 21.74102564  0.41794872]
#  [ 1.66142857 16.5755102   0.30428571]]

# %% [markdown]
# Ejecucion del algoritmo para k=5, obteniendose asi los centroides

# %% [markdown]
# ## Representacion grafica

# %%
#Predecting the cluster
labels = kmeans.predict(X)

# %%
#Getting the culster centers
C = kmeans.cluster_centers_
#5 colores porque k = 5
colores = ['green','red','yellow','blue','cyan']
asignar=[]
for row in labels:
    asignar.append(colores[row])
    
fig = plt.figure(figsize=(10,10))
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],X[:,2], c=asignar, s=70)
ax.scatter(C[:,0],C[:,1],C[:,2], marker='*',c=colores,s=1000)
plt.show()

# %% [markdown]
# El algoritmo k-Means a agrupado a los segmentos de clientes mediante sus preferencias mas marcadas vistas en los graficos anteriores, que basicamente son sabor amargo, calidad y aroma.

# %% [markdown]
# # Grafico de complemento

# %%
f1 = df_2['Malic_Acid'].values
f2 = df_2['Ash_Alcanity'].values

plt.figure(figsize=(10,6))
plt.scatter(f1,f2,c=asignar,s=70)
plt.scatter(C[:,0],C[:,1],marker='*',c=colores,s=1000)
plt.xlabel("Sabor amargo")
plt.ylabel("Calidad")
plt.show()

# %%
f1 = df_2['Malic_Acid'].values
f2 = df_2['Nonflavanoid_Phenols'].values

plt.figure(figsize=(10,6))
plt.scatter(f1,f2,c=asignar,s=70)
plt.scatter(C[:,0],C[:,1],marker='*',c=colores,s=1000)
plt.xlabel("Sabor amargo")
plt.ylabel("Aroma")
plt.show()

# %%
f1 = df_2['Ash_Alcanity'].values
f2 = df_2['Nonflavanoid_Phenols'].values

plt.figure(figsize=(10,6))
plt.scatter(f1,f2,c=asignar,s=70)
plt.scatter(C[:,0],C[:,1],marker='*',c=colores,s=1000)
plt.xlabel("Calidad")
plt.ylabel("Aroma")
plt.show()

# %% [markdown]
# # Cantidad de clientes por grupo

# %%
copy = pd.DataFrame()
copy['index']=df_2['index'].values
copy['Customer_Segment']=df_2['Customer_Segment'].values
copy['label']=labels;
cantidadGrupo = pd.DataFrame()
cantidadGrupo['color']=colores
cantidadGrupo['cantidad']=copy.groupby('label').size()
cantidadGrupo
# Out:
#     color  cantidad
# 0   green        57
# 1     red         8
# 2  yellow        18
# 3    blue        39
# 4    cyan        49

# %% [markdown]
# Se muestra la cantidad de clientes por grupo

# %% [markdown]
# ### Busqueda del representante de cada grupo

# %%
from sklearn.metrics import pairwise_distances_argmin_min
closest, _ = pairwise_distances_argmin_min(kmeans.cluster_centers_,X)
closest
# Out:
# array([165,  50, 162, 158,  18])

# %% [markdown]
# Para obtener estos representantes se utilizo distancia de euclidiana para sacar la distanciaentre los puntos de cada grupo con el objetivo de obtener un resultado que represente la mayor cantidad de datos del grupo

# %%
users=df_2['index'].values
for row in closest:
    print(df.iloc[row])
    print("*********")
# Out:
# index                   165.00
# Alcohol                  13.73
# Malic_Acid                4.36
# Ash                       2.26
# Ash_Alcanity             22.50
# Magnesium                88.00
# Total_Phenols             1.28
# Flavanoids                0.47
# Nonflavanoid_Phenols      0.52
# Proanthocyanins           1.15
# Color_Intensity           6.62
# Hue                       0.78
# OD280                     1.75
# Proline                 520.00
# Customer_Segment          3.00
# Name: 165, dtype: float64
# *********
# index                     50.00
# Alcohol                   13.05
# Malic_Acid                 1.73
# Ash                        2.04
# Ash_Alcanity              12.40
# Magnesium                 92.00
# Total_Phenols              2.72
# Flavanoids                 3.27
# Nonflavanoid_Phenols       0.17
# Proanthocyanins            2.91
# Color_Intensity            7.20
# Hue                        1.12
# OD280                      2.91
# ...

# %% [markdown]
# Se muestra las cualidades de cada representante de su grupo

# %% [markdown]
# # Conclusion

# %% [markdown]
# Gracias a la herramienta de agrupacion k-Means se obtuvieron del data freame distintos grupos los cuales representan las preferencias que tienen los consumidores a la hora de obtar por un vino u otro.
# Se separaron estos 3 grupos iniciales de clientes en 5 los cuales permiten visualizar con mayor exactitud esta preferencia.
